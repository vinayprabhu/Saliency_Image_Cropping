# %% [markdown]
# # Dataset-1: The Male-Gaze-Like (MGL) experiments spanning 336 images from Flickr

# %%
import pandas as pd
df_mgl=pd.read_csv('df_mgl_336.csv')
print(df_mgl.shape)
df_mgl.head(4)
# Out:
# (336, 29)
#                                             file_url  \
# 0  https://live.staticflickr.com/8576/15678067187...
# 1  https://live.staticflickr.com/7486/15863195222...
# 2  https://live.staticflickr.com/7483/15863847385...
# 3  https://live.staticflickr.com/7513/15678085497...
#
#                         file_name   album  width_image  height_image  \
# 0  15678067187_5df9778ea6_o_d.jpg  ama_14       1000.0        1500.0
# 1  15863195222_319e1e6588_o_d.jpg  ama_14       1000.0        1500.0
# 2  15863847385_e81fa7dd70_o_d.jpg  ama_14       1000.0        1500.0
# 3  15678085497_942f92cbcb_o_d.jpg  ama_14       1000.0        1500.0
#
#      size_image  width_round  height_round  sal_x_twitter  sal_y_twitter  ...  \
# 0  (1000, 1500)         1000          1500          862.0         1162.0  ...
# 1  (1000, 1500)         1000          1500          412.0          187.0  ...
# 2  (1000, 1500)         1000          1500          487.0          412.0  ...
# 3  (1000, 1500)         1000          1500          562.0          412.0  ...
#
#    crop_height_google  confidence_apple  sal_x_apple  sal_y_apple  \
# 0                 562          0.535154        463.0        253.0
# 1                 562          0.545259        448.0        165.0
# 2                 562          0.545817        433.0        341.0
# 3                 562          0.554018        536.0        341.0
#
#    top_left_x_apple  top_left_y_apple  crop_width_apple  crop_height_apple  \
# 0             185.0             190.0             814.0             1308.0
# 1             261.0             362.0             430.0             1135.0
# 2               0.0             262.0             718.0             1236.0
# 3              36.0             424.0             964.0             1076.0
#
#                                   saliency_map_apple  mgl
# 0  [0.0416734, 0.02431909, 0.026942655, 0.0137556...    1
# 1  [0.070013456, 0.05282114, 0.045947406, 0.04006...    0
# 2  [0.06788689, 0.05252986, 0.049423505, 0.047421...    0
# 3  [0.06382404, 0.04812908, 0.04656945, 0.0477425...    0
#
# [4 rows x 29 columns]

# %% [markdown]
# The descriptions of each of these 29 columns are as captured in ```col_descriptions_mgl_336.csv```

# %%
descr_mgl=pd.read_csv('col_descriptions_mgl_336.csv')
descr_mgl
# Out:
#                    column_name  \
# 0                     file_url
# 1                    file_name
# 2                        album
# 3                  width_image
# 4                 height_image
# 5                   size_image
# 6                  width_round
# 7                 height_round
# 8                sal_x_twitter
# 9                sal_y_twitter
# 10          top_left_x_twitter
# 11          top_left_y_twitter
# 12          crop_width_twitter
# 13         crop_height_twitter
# 14           confidence_google
# 15  importance_fraction_google
# 16           top_left_x_google
# 17           top_left_y_google
# 18           crop_width_google
# 19          crop_height_google
# 20            confidence_apple
# 21                 sal_x_apple
# 22                 sal_y_apple
# 23            top_left_x_apple
# 24            top_left_y_apple
# 25            crop_width_apple
# 26           crop_height_apple
# 27          saliency_map_apple
# 28                         mgl
#
#                                    column_explanation
# 0                                        Download URL
# 1                                    Name of the file
# 2                Name of the Flickr album Ex: espy_17
# 3                              Width of the raw image
# 4                             Height of the raw image
# 5                    Order pair of (width and height)
# 6        Width rounded to the nearest multiple of 250
# 7       Height rounded to the nearest multiple of 250
# 8   abscissa (x-coordinate) of the most salient po...
# 9   ordinate (y-coordinate) of the most salient po...
# 10  x-coordinate of the top-left crop-box accordin...
# 11  y-coordinate of the top-left crop-box accordin...
# 12     width of the crop-box according to Twitter-SIC
# 13    height of the crop-box according to Twitter-SIC
# 14  The confidence score associated with the salie...
# 15  The importance fraction of the salient region ...
# 16  abscissa (x-coordinate) of the top-left crop-b...
# 17  ordinate (y-coordinate) of the top-left crop-b...
# 18      width of the crop-box according to Google-SIC
# 19     height of the crop-box according to Google-SIC
# 20  The confidence score associated with the salie...
# 21  abscissa (x-coordinate) of the most salient po...
# 22  ordinate (y-coordinate) of the most salient po...
# 23  abscissa (x-coordinate) of the top-left crop-b...
# 24  ordinate (y-coordinate) of the top-left crop-b...
# 25       width of the crop-box according to Apple-SIC
# 26      height of the crop-box according to Apple-SIC
# 27  The saliency values associated with the 68x68 ...
# 28  Binary indicator variable that denotes whether...

# %% [markdown]
# # Dataset-2: The CFD experiments spanning 3k images from CFD across 6 RG categories

# %%
df_cfd=pd.read_csv('df_cfd_3k.csv')
print(df_cfd.shape)
df_cfd.head(4)
# Out:
# (3000, 37)
#           file_name              file_top           file_bottom combination  \
# 0  BMBF_image_0.png  CFD-BF-012-001-N.jpg  CFD-BM-005-003-N.jpg        BMBF
# 1  BMBF_image_1.png  CFD-BF-017-003-N.jpg  CFD-BM-218-132-N.jpg        BMBF
# 2  BMBF_image_2.png  CFD-BF-233-116-N.jpg  CFD-BM-044-001-N.jpg        BMBF
# 3  BMBF_image_3.png  CFD-BF-036-027-N.jpg  CFD-BM-212-117-N.jpg        BMBF
#
#    sal_x_twitter  sal_y_twitter  top_left_x_twitter  top_left_y_twitter  \
# 0            375            375                   0                 212
# 1            375           2475                   0                2312
# 2            225            375                   0                 212
# 3            225           2475                   0                2312
#
#    crop_width_twitter  crop_height_twitter  ...  top_left_x_apple  \
# 0                 583                  326  ...        127.300053
# 1                 583                  326  ...        125.618151
# 2                 583                  326  ...        157.035997
# 3                 583                  326  ...        155.261409
#
#    top_left_y_apple  crop_width_apple  crop_height_apple  \
# 0          0.000000        319.274691        3000.000000
# 1          0.000000        316.107482        3000.000000
# 2        972.353697        266.056601        2015.235007
# 3          4.123449        277.578079        2994.518638
#
#                                          file_const     file_ind  \
# 0  ('CFD-BF-012-001-N.jpg', 'CFD-BM-005-003-N.jpg')  image_0.png
# 1  ('CFD-BF-017-003-N.jpg', 'CFD-BM-218-132-N.jpg')  image_1.png
# 2  ('CFD-BF-233-116-N.jpg', 'CFD-BM-044-001-N.jpg')  image_2.png
# 3  ('CFD-BF-036-027-N.jpg', 'CFD-BM-212-117-N.jpg')  image_3.png
#
#    survived_member_twitter  survived_twitter  survived_member_apple  \
# 0                      top                BF                    top
# 1                   bottom                BM                    top
# 2                      top                BF                 bottom
# 3                   bottom                BM                 bottom
#
#    survived_apple
# 0              BF
# 1              BF
# 2              BM
# 3              BM
#
# [4 rows x 37 columns]

# %% [markdown]
# The descriptions of each of these 37 columns are as captured in ```col_descriptions_cfd_3k.csv```

# %%
descr_cfd=pd.read_csv('col_descriptions_cfd_3k.csv')
descr_cfd
# Out:
#                    column_name  \
# 0                    file_name
# 1                     file_top
# 2                  file_bottom
# 3                  combination
# 4                sal_x_twitter
# 5                sal_y_twitter
# 6           top_left_x_twitter
# 7           top_left_y_twitter
# 8           crop_width_twitter
# 9          crop_height_twitter
# 10           confidence_google
# 11  importance_fraction_google
# 12           top_left_x_google
# 13           top_left_y_google
# 14          top_right_x_google
# 15          top_right_y_google
# 16       bottom_right_x_google
# 17       bottom_right_y_google
# 18        bottom_left_x_google
# 19        bottom_left_y_google
# 20             survived_google
# 21      survived_member_google
# 22           crop_width_google
# 23          crop_height_google
# 24            confidence_apple
# 25                 sal_x_apple
# 26                 sal_y_apple
# 27            top_left_x_apple
# 28            top_left_y_apple
# 29            crop_width_apple
# 30           crop_height_apple
# 31                  file_const
# 32                    file_ind
# 33     survived_member_twitter
# 34            survived_twitter
# 35       survived_member_apple
# 36              survived_apple
#
#                                    column_description
# 0   Name of the image file in the format of RGBott...
# 1   CFD image name that was chosen to be the top-i...
# 2   CFD image name that was chosen to be the botto...
# 3   RG: Race-Gender combination in the format of R...
# 4   x-coordinate of the most salient point accordi...
# 5   y-coordinate of the most salient point accordi...
# 6   x-coordinate of the top-left crop-box accordin...
# 7   y-coordinate of the top-left crop-box accordin...
# 8      width of the crop-box according to Twitter-SIC
# 9     height of the crop-box according to Twitter-SIC
# 10  The confidence score associated with the salie...
# 11  The importance fraction of the salient region ...
# 12  x-coordinate of the top-left crop-box accordin...
# 13  y-coordinate of the top-left crop-box accordin...
# 14  x-coordinate of the top-right crop-box accordi...
# 15  y-coordinate of the top-right crop-box accordi...
# 16  x-coordinate of the bottom-right crop-box acco...
# 17  y-coordinate of the bottom-right crop-box acco...
# 18  x-coordinate of the bottom-left crop-box accor...
# 19  y-coordinate of the bottom-left crop-box accor...
# 20  The RG combination that survived the cropping ...
# 21  Indicates which of the two images (top or bott...
# 22      width of the crop-box according to Google-SIC
# 23     height of the crop-box according to Google-SIC
# 24  The top/bottom combination that survived the c...
# 25  x-coordinate of the most salient point accordi...
# 26  y-coordinate of the most salient point accordi...
# 27  x-coordinate of the top-left crop-box accordin...
# 28  y-coordinate of the top-left crop-box accordin...
# 29       width of the crop-box according to Apple-SIC
# 30      height of the crop-box according to Apple-SIC
# 31  Ordered pair of the constituent file names  fo...
# 32   Index of the file in the format of image_{n}.png
# 33  Indicates which of the two images (top or bott...
# 34  The RG combination that survived the cropping ...
# 35  Indicates which of the two images (top or bott...
# 36  The RG combination that survived the cropping ...
